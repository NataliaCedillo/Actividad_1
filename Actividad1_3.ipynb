# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaCedillo/Actividad_1/blob/main/Actividad1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()

# %%
datos = pd.read_excel('Inmuebles.xlsx', header = 1)
#datos = datos.drop(columns = 'Referencia', index = 1)
datos
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# ...          ...        ...         ...       ...        ...         ...
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3334        3335 2007-04-30       Suelo     Venta  Tarragona        78.0
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %%
datos['Fecha_Alta'] = datos['Fecha_Alta'].astype(str)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3337 entries, 0 to 3336
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Referencia    3337 non-null   int64
#  1   Fecha_Alta    3337 non-null   object
#  2   Tipo          3337 non-null   object
#  3   Operación     3337 non-null   object
#  4   Provincia     3337 non-null   object
#  5   Superficie    3335 non-null   float64
#  6   Precio Venta  3335 non-null   float64
#  7   Fecha Venta   2759 non-null   datetime64[ns]
#  8   Vendedor      2759 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 234.8+ KB

# %%
f2 = datos[(datos['Fecha_Alta']=='2007-04-29') | (datos['Fecha_Alta']=='2004-01-02')]
f2
# Out:
#       Referencia  Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 3              4  2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5  2004-01-02       Suelo     Venta  Tarragona       152.0
# 3331        3332  2007-04-29     Oficina     Venta     Lleida       190.0
# 3332        3333  2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334  2007-04-29        Piso  Alquiler     Girona        55.0
#
#       Precio Venta Fecha Venta Vendedor
# 3              NaN  2004-04-27    Jesús
# 4         185000.0  2004-07-10    María
# 3331     1031320.0         NaT      NaN
# 3332     1450644.0         NaT      NaN
# 3333      454080.0         NaT      NaN

# %%
f3 = datos[(datos['Tipo']=='Parking') | (datos['Tipo']=='Local') | (datos['Tipo']=='Industrial') | (datos['Tipo']=='Piso')]
f3
# Out:
#       Referencia  Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1  2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2  2004-01-01       Local     Venta     Girona       185.0
# 3              4  2004-01-02     Parking  Alquiler     Girona       285.0
# 5              6  2004-01-03  Industrial  Alquiler     Girona       131.0
# 6              7  2004-01-03     Parking  Alquiler  Tarragona         NaN
# ...          ...         ...         ...       ...        ...         ...
# 3330        3331  2007-04-27       Local     Venta     Girona       110.0
# 3332        3333  2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334  2007-04-29        Piso  Alquiler     Girona        55.0
# 3335        3336  2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337  2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# ...

# %%
f4 = datos[(datos['Provincia']=='Girona') & (datos['Superficie']>100)]
f4
# Out:
#       Referencia  Fecha_Alta        Tipo Operación Provincia  Superficie  \
# 1              2  2004-01-01       Local     Venta    Girona       185.0
# 3              4  2004-01-02     Parking  Alquiler    Girona       285.0
# 5              6  2004-01-03  Industrial  Alquiler    Girona       131.0
# 7              8  2004-01-03     Oficina     Venta    Girona       235.0
# 10            11  2004-01-04     Oficina  Alquiler    Girona       124.0
# ...          ...         ...         ...       ...       ...         ...
# 3299        3300  2007-04-12       Local  Alquiler    Girona       156.0
# 3303        3304  2007-04-12        Piso     Venta    Girona       128.0
# 3306        3307  2007-04-14     Parking     Venta    Girona       221.0
# 3316        3317  2007-04-20        Casa     Venta    Girona       247.0
# 3330        3331  2007-04-27       Local     Venta    Girona       110.0
#
#       Precio Venta Fecha Venta Vendedor
# 1        1945424.0  2004-04-19    Pedro
# ...

# %%
f5 = datos[(datos['Precio Venta'] > 1000000) | (datos['Vendedor']=='Carmen') | (datos['Vendedor']=='Joaquin')]
f5
# Out:
#       Referencia  Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1  2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2  2004-01-01       Local     Venta     Girona       185.0
# 7              8  2004-01-03     Oficina     Venta     Girona       235.0
# 8              9  2004-01-04        Piso  Alquiler     Lleida       108.0
# 9             10  2004-01-04     Parking     Venta     Lleida       299.0
# ...          ...         ...         ...       ...        ...         ...
# 3325        3326  2007-04-25  Industrial  Alquiler  Barcelona       296.0
# 3328        3329  2007-04-26        Piso     Venta  Barcelona       264.0
# 3331        3332  2007-04-29     Oficina     Venta     Lleida       190.0
# 3332        3333  2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3336        3337  2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# ...

# %%
f6 = datos[~(datos['Provincia']=='Barcelona')]
f6

# %%
#Analizar agrupaciones de una columnas
datos2 = f6.groupby(['Provincia'])['Provincia'].count()
datos2
# Out:
# Provincia
# Girona       861
# Lleida       783
# Tarragona    855
# Name: Provincia, dtype: int64

# %% [markdown]
# - Utilizar el nuevo repositorio con el nombre: Actividad 1
# - Agregar el archivo: Inmuebles.xlsx
# - Aplicar los siguientes filtros:
# 1. Eliminar la fila “0” de “Unnamed” y Eliminar la columna “0” y la columna “Referencia”
# 2. Todos las registros de “Fecha Alta : igual a 2007-04-29 00:00:00 y a 2004-01-02 00:00:00
# 3. Todos los registros de “ Tipo: parking, local, industrial y piso”
# 4. Todos los registros con “Provincia” igual a “Girona” y con “Superficie” mayor a “100”
# 5. Todos los registros con “Precio Venta: mayor a 1000,000” o “vendedor” igual a “Carmen o Joaquin”
# 6. Todos los registros que no sean de “Provincia : Barcelona“
# 7. Todos los registros que no sean de “Operación: alquiler “ ni “Tipo: oficina“
#
# - Crear el archivo en Google Colab, respaldarlo en GitHub.
# - -Por cada filtro agregar un comentario en cada COMMIT y agregar el archivo .csv de cada filtro

# %%
f7 =  datos[~(datos['Operación']=='Alquiler') & ~(datos['Tipo']=='Oficina')]
f7
# Out:
#       Referencia  Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 1              2  2004-01-01       Local     Venta     Girona       185.0
# 4              5  2004-01-02       Suelo     Venta  Tarragona       152.0
# 9             10  2004-01-04     Parking     Venta     Lleida       299.0
# 11            12  2004-01-04  Industrial     Venta     Girona       187.0
# 12            13  2004-01-04     Parking     Venta  Barcelona         NaN
# ...          ...         ...         ...       ...        ...         ...
# 3328        3329  2007-04-26        Piso     Venta  Barcelona       264.0
# 3329        3330  2007-04-27     Parking     Venta  Barcelona        88.0
# 3330        3331  2007-04-27       Local     Venta     Girona       110.0
# 3334        3335  2007-04-30       Suelo     Venta  Tarragona        78.0
# 3336        3337  2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# ...

# %%
#Analizar agrupaciones de una columnas
datos3 = f7.groupby(['Tipo'])['Tipo'].count()
datos3
# Out:
# Tipo
# Casa          224
# Industrial    254
# Local         238
# Parking       257
# Piso          230
# Suelo         232
# Name: Tipo, dtype: int64

# %%
f2.to_csv('f2.csv')
from google.colab import files
files.download('f2.csv')

f3.to_csv('f3.csv')
from google.colab import files
files.download('f3.csv')

f4.to_csv('f4.csv')
from google.colab import files
files.download('f4.csv')

f5.to_csv('f5.csv')
from google.colab import files
files.download('f5.csv')

f6.to_csv('f6.csv')
from google.colab import files
files.download('f6.csv')

f7.to_csv('f7.csv')
from google.colab import files
files.download('f7.csv')
