# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaCedillo/Actividad_1/blob/main/Actividad1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()

# %% [markdown]
# 1. Crear un nuevo repositorio con el nombre: Extracción de datos
#
# 2. Agregar al archivo: Detalle precios y Productos fabricados 2022.xlsx
#
# 3. Aplicar los 9 filtros descritos en el archivo1-Extraccion_datps.ipynb
#
# 4. Crear el archivo en Google Colab, respaldarlo en GitHub
#
# 5. Por cada filtro agregar un archivo csv con el nombre de cad filtro y describir cuales fueron las variables filtradas dentro del script
#
# 6. Subir el link del repositorio a CANVAS para Evaluacion

# %%
df = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
filtro1 = df[df['NOMBRE_VENDEDOR'] == 'LETICIA RAMIREZ HERNANDEZ']
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# 5               PÚBLICO EN GENERAL     2       BP00243
# 7        ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %%
#filtro2 = df.iloc[40:1000,:]
filtro2 = df.iloc[[1111, 85, 30], :]
filtro2
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1111  F39223 2022-09-30  LETICIA RAMIREZ HERNANDEZ
# 85    F37187 2022-01-25  LETICIA RAMIREZ HERNANDEZ
# 30    F37083 2022-01-10             ALFREDO CANELA
#
#                              NOMBRE_CLIENTE  CANT   CVE_ART  \
# 1111  SERVICIOS ESPECIALIZADOS DE QUERETARO     4  CAS00013
# 85             ROQUE AVINAR RAMIREZ SERRANO    12  TEA00058
# 30                PEDRO ANTONIO SOTO IBARRA     6  TUE00247
#
#                                          DESCR  PRECIO_UNITARIO  \
# 1111   CAS INOX. 3/8"Øx4" LONG 500W 120V CABLE           530.64
# 85    TER J 1/8"Øx115mm LONG EXT. DE 1220mm CL           431.50
# 30      TUB INOX 7/16"ØX490MM U ESP 3200W 220V           856.04
#
#       COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 1111            0.00                    325.23           2122.56
# 85             95.96                     95.96           5178.00
# ...

# %%
#filtro3 = df.iloc[ : , [3, 2,5]]
filtro3 = df.iloc[ : ,3:6]
filtro3
# Out:
#                     NOMBRE_CLIENTE  CANT       CVE_ART
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...                            ...   ...           ...
# 1421     LUIS ENRIQUE PATIÑO PEREZ     6  CS12F1040A00
# 1422     LUIS ENRIQUE PATIÑO PEREZ     6  CS12H1050A00
# 1423          SEVEN DAYS ALL SPORT     3      TUE00394
# 1424           REVUELTA MONTECARLO     1      TUA00470
# 1425                CPEG SOLUTIONS    10       RB00007
#
# [1426 rows x 3 columns]

# %%
df1 = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col = 2)
df1
# Out:
#                           CVE_DOC  FECHA_DOC                NOMBRE_CLIENTE  \
# NOMBRE_VENDEDOR
# LETICIA RAMIREZ HERNANDEZ  F37034 2022-01-05            PÚBLICO EN GENERAL
# LETICIA RAMIREZ HERNANDEZ  F37036 2022-01-05  JUAN ANTONIO RESENDIZ UGALDE
# DIEGO ARMANDO LEON DURAN   F37041 2022-01-05     ANA BARBARA CRUZ PALACIOS
# DIEGO ARMANDO LEON DURAN   F37042 2022-01-05          OMAR RODRIGUEZ GOMEZ
# LETICIA RAMIREZ HERNANDEZ  F37043 2022-01-05            PÚBLICO EN GENERAL
# ...                           ...        ...                           ...
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39835 2022-12-23          SEVEN DAYS ALL SPORT
# LETICIA RAMIREZ HERNANDEZ  F39837 2022-12-23           REVUELTA MONTECARLO
# AARON NUÑO CORDOVA         F39838 2022-12-23                CPEG SOLUTIONS
#
#                            CANT       CVE_ART  \
# ...

# %%
filtro4 = df1.loc[['AARON NUÑO CORDOVA', 'LETICIA RAMIREZ HERNANDEZ'], ['CANT', 'DESCR']]
filtro4
# Out:
#                            CANT                                     DESCR
# NOMBRE_VENDEDOR
# AARON NUÑO CORDOVA            2                    REPARACION DE TERMOPAR
# AARON NUÑO CORDOVA            8  TUB INOX 5/16"ØX50CM 4000W240V "J" 1"NPT
# AARON NUÑO CORDOVA           20      TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 2 MT
# AARON NUÑO CORDOVA            2     BB INOX 40MMØX60MM 300W 240V EXT.30CM
# AARON NUÑO CORDOVA            2  TER K 1/4"Øx79CM DOBLEZ 90° C.STD MAC/HE
# ...                         ...                                       ...
# LETICIA RAMIREZ HERNANDEZ     3  TER J 3/16"ØX1/2" EXT3MT MALLA INOX  Z/E
# LETICIA RAMIREZ HERNANDEZ     6      CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# LETICIA RAMIREZ HERNANDEZ     6       CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# LETICIA RAMIREZ HERNANDEZ     3  TUB INOX 5/16"ØX300MM 5300W 220V "M" ESP
# LETICIA RAMIREZ HERNANDEZ     1  TUB INOX 1/2"ØX500MM 10KW 220V 2 1/2"NPT
#
# [967 rows x 2 columns]

# %%
filtro5 = df.head(8)
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL     1  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                   PÚBLICO EN GENERAL     2   BP00242
# 5                   PÚBLICO EN GENERAL     2   BP00243
# 6  AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 7            ANA BARBARA CRUZ PALACIOS     3    TP0001
#
# ...

# %%
filtro6 = df[df['COSTO_TOTAL_CALCULADO']>100]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2               ANA BARBARA CRUZ PALACIOS     7        TP0007
# 4                      PÚBLICO EN GENERAL     2       BP00242
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# ...

# %%
filtro7 = df[(df['COSTO_UNITARIO'] < 500) & (df['CANT'] > 2)]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ  ANA BARBARA CRUZ PALACIOS
# 15    F37058 2022-01-05   DIEGO ARMANDO LEON DURAN         MOLINERA DE MEXICO
# 17    F37060 2022-01-05   DIEGO ARMANDO LEON DURAN    OSCAR VALDEZ GUADARRAMA
# 18    F37061 2022-01-05             ALFREDO CANELA                   ELICAMEX
# ...      ...        ...                        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ                     TORJJS
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
# ...

# %%
filtro8 = filtro7 = df[(df['COSTO_UNITARIO'] < 500) | (df['CANT'] > 2)]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
filtro9 = df[~(df['CANT'] == 2) & ~(df['MARGEN_UNITARIO_CALCULADO'] < 100)]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0                      PÚBLICO EN GENERAL     1      TUE00244
# 1            JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2               ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3                    OMAR RODRIGUEZ GOMEZ     1        TP0001
# ...

# %%
filtro1.to_csv('Filtro1.csv')
from google.colab import files
files.download('Filtro1.csv')

# %%
filtro2.to_csv('Filtro2.csv')
from google.colab import files
files.download('Filtro2.csv')

# %%
filtro3.to_csv('Filtro3.csv')
from google.colab import files
files.download('Filtro3.csv')

# %%
filtro4.to_csv('Filtro4.csv')
from google.colab import files
files.download('Filtro4.csv')

# %%
filtro5.to_csv('Filtro5.csv')
from google.colab import files
files.download('Filtro5.csv')

# %%
filtro6.to_csv('Filtro6.csv')
from google.colab import files
files.download('Filtro6.csv')

# %%
filtro7.to_csv('Filtro7.csv')
from google.colab import files
files.download('Filtro7.csv')

# %%
filtro8.to_csv('Filtro8.csv')
from google.colab import files
files.download('Filtro8.csv')

# %%
filtro9.to_csv('Filtro9.csv')
from google.colab import files
files.download('Filtro9.csv')
